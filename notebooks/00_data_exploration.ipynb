# %%
import sys
sys.executable
# Out:
# '/opt/anaconda3/envs/alphalab/bin/python3.11'

# %%
from alphalab.data.download import get_prices_yahoo
import matplotlib.pyplot as plt

df = get_prices_yahoo("SPY", "2022-01-01", "2023-01-01")
df.head()
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker             SPY         SPY         SPY         SPY         SPY
# Date
# 2022-01-03  453.210358  477.709991  477.850006  473.850006  476.299988
# 2022-01-04  453.058624  477.549988  479.980011  475.579987  479.220001
# 2022-01-05  444.358917  468.380005  477.980011  468.279999  477.160004
# 2022-01-06  443.941437  467.940002  470.820007  465.429993  467.890015
# 2022-01-07  442.186371  466.089996  469.200012  464.649994  467.950012
#
# Price          Volume
# Ticker            SPY
# Date
# 2022-01-03   72668200
# 2022-01-04   71178700
# 2022-01-05  104538900
# 2022-01-06   86858900
# 2022-01-07   85111600

# %%
df["Adj Close"].plot(figsize=(10,4), title="SPY Adjusted Close (2022)")
plt.ylabel("Price")
plt.show()

# %%
df.to_csv("../data/raw/SPY_2022.csv")
print("Saved to data/raw/SPY_2022.csv")
# Out:
# Saved to data/raw/SPY_2022.csv
